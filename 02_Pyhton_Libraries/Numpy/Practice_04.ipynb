# %%
import numpy as np

sales_data = np.array([
    [1, 200, 300, 250],   # Day 1: [Day, R1, R2, R3]
    [2, 220, 280, 270],   # Day 2
    [3, 210, 320, 260],   # Day 3
    [4, 230, 310, 280],   # Day 4
    [5, 240, 330, 300]    # Day 5
])

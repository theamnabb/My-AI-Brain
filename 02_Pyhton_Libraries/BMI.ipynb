# %%
print("BMI Calculator App ")

userWeight = float(input("Enter your weight in kg: "))
userHeight = float(input("Enter your height in meters: "))

userHeightSquared = userHeight ** 2
userBMI = userWeight / userHeightSquared

print(f"Your BMI is: {userBMI:.2f}")

match True:
    case _ if userBMI < 18.5:
        print("You are underweight.")
    case _ if 18.5 <= userBMI < 25:
        print("You have a normal weight.")
    case _ if 25 <= userBMI < 30:
        print("You are overweight.")
    case _ if userBMI >= 30:
        print("You are obese.")
    case _:
        print("Invalid BMI value.")
# Out:
# BMI Calculator App
# Your BMI is:  1.88
# You are underweight.

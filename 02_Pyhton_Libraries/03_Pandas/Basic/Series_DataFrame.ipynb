# %%
import pandas as pd

# Example: marks of students
marks = pd.Series([85, 90, 78, 92, 88])
print(marks)
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# dtype: int64

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# DataFrame :A DataFrame is like a full Excel sheet (rows(indices) + columns(name)). )
data = {
    "Name": ["Ali", "Sara", "Ahmed", "Zara", "Hassan", "Bilal", "Usman"],
    "Age": [23, 21, 25, 22, 24, 20, 27]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0     Ali   23
# 1    Sara   21
# 2   Ahmed   25
# 3    Zara   22
# 4  Hassan   24
# 5   Bilal   20
# 6   Usman   27

# %% [markdown]
# # **Basic Attributes**

# %%
# Basic attributes: .shape, .columns, .index, .dtypes

print(df.shape)  # Returns the shape of the DataFrame (rows, columns)
print(df.columns)  # Returns the column names of the DataFrame
# Out:
# (7, 2)
# Index(['Name', 'Age'], dtype='object')

# %%
# Read data from exiting file 

df = pd.read_csv('D:/My-AI-Brain/02_Pyhton_Libraries/03_Pandas/Basic/SampleData/sales_data_sample.csv',encoding='Latin1')
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# Data from json file

df = pd.read_json('D:/My-AI-Brain/02_Pyhton_Libraries/03_Pandas/Basic/SampleData/sample_Data.json')
print(df)
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
# head()
df = pd.DataFrame(data)
print(df)
print("First 5 rows:")
print(df.head())
# tail()
print('====tail()====')
print("\nLast 5 rows:")
print(df.tail())

print('====info()====')
print(df.info())

print('====describe()====')
print(df.describe())
# Out:
#      Name  Age
# 0     Ali   23
# 1    Sara   21
# 2   Ahmed   25
# 3    Zara   22
# 4  Hassan   24
# 5   Bilal   20
# 6   Usman   27
# First 5 rows:
#      Name  Age
# 0     Ali   23
# 1    Sara   21
# 2   Ahmed   25
# 3    Zara   22
# 4  Hassan   24
# ====tail()====
#
# Last 5 rows:
#      Name  Age
# 2   Ahmed   25
# 3    Zara   22
# 4  Hassan   24
# 5   Bilal   20
# 6   Usman   27
# ====info()====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 244.0+ bytes
# None
# ====describe()====
#              Age
# count   7.000000
# mean   23.142857
# std     2.410295
# min    20.000000
# 25%    21.500000
# 50%    23.000000
# 75%    24.500000
# max    27.000000
